# %% [markdown]
# **Pandas practice**

# %%
#Importing libraries
import pandas as pd
import seaborn as sns

#Load dataset
df = sns.load_dataset('titanic')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
#creating an excel/csv file of dataset
df.to_excel('titanic2.xlsx') 
df.to_csv('titanic2.csv')

# %%
#Reading files
df = pd.read_excel('titanic2.xlsx')
df = pd.read_csv('titanic2.csv')

# %%
#showing how the data looks like
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   891 non-null    int64
#  1   survived     891 non-null    int64
#  2   pclass       891 non-null    int64
#  3   sex          891 non-null    object
#  4   age          714 non-null    float64
#  5   sibsp        891 non-null    int64
#  6   parch        891 non-null    int64
#  7   fare         891 non-null    float64
#  8   embarked     889 non-null    object
#  9   class        891 non-null    object
#  10  who          891 non-null    object
#  11  adult_male   891 non-null    bool
#  12  deck         203 non-null    object
#  13  embark_town  889 non-null    object
#  14  alive        891 non-null    object
#  15  alone        891 non-null    bool
# dtypes: bool(2), float64(2), int64(5), object(7)
# memory usage: 99.3+ KB

# %%
#showing the statistics of data
df.describe()
# Out:
#        Unnamed: 0    survived      pclass         age       sibsp       parch  \
# count  891.000000  891.000000  891.000000  714.000000  891.000000  891.000000
# mean   445.000000    0.383838    2.308642   29.699118    0.523008    0.381594
# std    257.353842    0.486592    0.836071   14.526497    1.102743    0.806057
# min      0.000000    0.000000    1.000000    0.420000    0.000000    0.000000
# 25%    222.500000    0.000000    2.000000   20.125000    0.000000    0.000000
# 50%    445.000000    0.000000    3.000000   28.000000    0.000000    0.000000
# 75%    667.500000    1.000000    3.000000   38.000000    1.000000    0.000000
# max    890.000000    1.000000    3.000000   80.000000    8.000000    6.000000
#
#              fare
# count  891.000000
# mean    32.204208
# std     49.693429
# min      0.000000
# 25%      7.910400
# 50%     14.454200
# 75%     31.000000
# max    512.329200

# %%
#showing the top rows of data
df.head(15)
# Out:
#     Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare  \
# 0            0         0       3    male  22.0      1      0   7.2500
# 1            1         1       1  female  38.0      1      0  71.2833
# 2            2         1       3  female  26.0      0      0   7.9250
# 3            3         1       1  female  35.0      1      0  53.1000
# 4            4         0       3    male  35.0      0      0   8.0500
# 5            5         0       3    male   NaN      0      0   8.4583
# 6            6         0       1    male  54.0      0      0  51.8625
# 7            7         0       3    male   2.0      3      1  21.0750
# 8            8         1       3  female  27.0      0      2  11.1333
# 9            9         1       2  female  14.0      1      0  30.0708
# 10          10         1       3  female   4.0      1      1  16.7000
# 11          11         1       1  female  58.0      0      0  26.5500
# ...

# %%
#showing the bottom rows of data
df.tail(15)
# Out:
#      Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare  \
# 876         876         0       3    male  20.0      0      0   9.8458
# 877         877         0       3    male  19.0      0      0   7.8958
# 878         878         0       3    male   NaN      0      0   7.8958
# 879         879         1       1  female  56.0      0      1  83.1583
# 880         880         1       2  female  25.0      0      1  26.0000
# 881         881         0       3    male  33.0      0      0   7.8958
# 882         882         0       3  female  22.0      0      0  10.5167
# 883         883         0       2    male  28.0      0      0  10.5000
# 884         884         0       3    male  25.0      0      0   7.0500
# 885         885         0       3  female  39.0      0      5  29.1250
# 886         886         0       2    male  27.0      0      0  13.0000
# 887         887         1       1  female  19.0      0      0  30.0000
# ...

# %%
#Creating a dataframe
df = pd.DataFrame({'A': [1,2,3], 'B': [4,5,6]})
df
# Out:
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6

# %%
#Creating dataframe using numpy
import numpy as np
df = pd.DataFrame(np.random.randn(10, 5))
df
# Out:
#           0         1         2         3         4
# 0 -1.059518 -0.859439 -0.974157 -1.474781  0.629964
# 1  0.360023  1.144061 -1.187280  1.482198 -1.518716
# 2 -0.104030  0.794820  1.578681 -0.072839 -0.367159
# 3 -1.204933 -0.928355  1.707674  0.541541  0.640643
# 4 -0.922791 -0.106636 -0.202400  1.777952  0.845262
# 5 -0.320236 -0.524917 -0.889490  0.787807 -0.556989
# 6  1.012054 -0.376427  0.277928 -0.497316  0.994142
# 7 -0.077971 -1.071814 -0.354748 -0.490140  0.853501
# 8 -2.343304  1.582693 -0.044018  0.239810  0.987208
# 9 -1.135963 -1.180460 -0.815731 -1.299169 -1.493564

# %%
#Changing columns into Alphabets
df = pd.DataFrame(np.random.rand(4,4), columns=list('ABCD'))
df
# Out:
#           A         B         C         D
# 0  0.882841  0.185866  0.950552  0.760636
# 1  0.533591  0.292318  0.175202  0.065795
# 2  0.233790  0.561267  0.668597  0.585983
# 3  0.816090  0.044104  0.997961  0.301129

# %%
#Changing names of columns
df.columns = ['col_A','col_B','col_C','col_D']
df
# Out:
#       col_A     col_B     col_C     col_D
# 0  0.882841  0.185866  0.950552  0.760636
# 1  0.533591  0.292318  0.175202  0.065795
# 2  0.233790  0.561267  0.668597  0.585983
# 3  0.816090  0.044104  0.997961  0.301129

# %%
#Adding prefixes and suffixes to the columns
df = df.add_prefix("01")
df = df.add_suffix("_00")
df
# Out:
#    01col_A_00  01col_B_00  01col_C_00  01col_D_00
# 0    0.882841    0.185866    0.950552    0.760636
# 1    0.533591    0.292318    0.175202    0.065795
# 2    0.233790    0.561267    0.668597    0.585983
# 3    0.816090    0.044104    0.997961    0.301129

# %%
#showing data in reverse order
df.loc[::-1].head()
# Out:
#    01col_A_00  01col_B_00  01col_C_00  01col_D_00
# 3    0.816090    0.044104    0.997961    0.301129
# 2    0.233790    0.561267    0.668597    0.585983
# 1    0.533591    0.292318    0.175202    0.065795
# 0    0.882841    0.185866    0.950552    0.760636

# %%
df = sns.load_dataset('titanic')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
#select a specific datatype
df.select_dtypes('object').head()
# Out:
#       sex embarked    who  embark_town alive
# 0    male        S    man  Southampton    no
# 1  female        C  woman    Cherbourg   yes
# 2  female        S  woman  Southampton   yes
# 3  female        S  woman  Southampton   yes
# 4    male        S    man  Southampton    no

# %%
#Exclude a specific data type
df.select_dtypes(exclude='object').head()
# Out:
#    survived  pclass   age  sibsp  parch     fare  class  adult_male deck  \
# 0         0       3  22.0      1      0   7.2500  Third        True  NaN
# 1         1       1  38.0      1      0  71.2833  First       False    C
# 2         1       3  26.0      0      0   7.9250  Third       False  NaN
# 3         1       1  35.0      1      0  53.1000  First       False    C
# 4         0       3  35.0      0      0   8.0500  Third        True  NaN
#
#    alone
# 0  False
# 1  False
# 2   True
# 3  False
# 4   True

# %%
#Converting data types
df.astype({'sex': 'category'}).dtypes
# Out:
# survived          int64
# pclass            int64
# sex            category
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
import pandas as pd
import seaborn as sns
df = sns.load_dataset('titanic')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
bins = [0,1,5,12,18,30,50,80]
labels = ['babies','Toddlers','Kids','Teens','Young','Middle Aged','Elder']
pd.cut(df['age'], bins=bins, labels=labels)
df['Age_Groups'] = pd.cut(df['age'], bins=bins, labels=labels)

# %%
df['Age_Groups'].value_counts()
# Out:
# Age_Groups
# Young          270
# Middle Aged    241
# Teens           70
# Elder           64
# Toddlers        30
# Kids            25
# babies          14
# Name: count, dtype: int64
